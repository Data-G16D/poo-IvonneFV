# %% [markdown]
# ##Ejercicio 1
# Realizar un programa que conste de una clase llamada Alumno que tenga como atributos el nombre y la nota del alumno. Definir los métodos para inicializar sus atributos, imprimirlos y mostrar un mensaje con el resultado de la nota y si ha aprobado o no.

# %%
class Alumno:
  def __init__(self, nombre, nota):
    self.nombre=nombre
    self.nota=nota
  def calificar (self):
    if self.nota>=6:
      #print("Aprobaste", self.nombre)
      return "Aprobaste "+ self.nombre
    else:
      #print("Reprobasete :(", self.nombre)
      return "Aprobaste "+ self.nombre

p1=Alumno("POLET", 6)
p2=Alumno("MARIA", 5)
p2.calificar()

# %% [markdown]
# ##Ejercicio 2
# Realizar un programa que tenga una clase Persona con las siguientes características. La clase tendrá como atributos el nombre y la edad de una persona. Implementar los métodos necesarios para inicializar los atributos, mostrar los datos e indicar si la persona es mayor de edad o no.

# %%
class Datos:
  #Función principal
  def __init__(self, nombre, edad):
    self.nombre=nombre
    self.edad=edad
 #función para evaluar si es  mayor de edad o no
  def evaluar (self):
    if self.edad>=18:
      return "Mayor de edad "+ self.nombre
    else:
      return "Menor de edad "+ self.nombre

p1=Datos("POLET", 6)
p2=Datos("MARIA", 25)
print(p2.evaluar())
print(p1.evaluar())

# %%
class Datos:
    nombre=""
    edad=""
    def nombre_edad(self):
        print("Nombre : ",self.nombre)
        print("Años :",self.edad)
        if self.edad>18:
            print(self.nombre,"sí es mayor de edad")
        else:
            print(self.nombre,"no es mayor de edad")

# Datos del caso1:Mayor de Edad
caso1=Datos()
caso1.nombre="Carlos"     
caso1.edad=21              
caso1.nombre_edad() 
# Datos del caso2:Menor de edad
caso2=Datos()
caso2.nombre="Carlos Segundo"     
caso2.edad=8             
caso2.nombre_edad()

# %% [markdown]
# ##Ejercicio 3
# Desarrollar un programa que cargue los datos de un triángulo. Implementar una clase con los métodos para inicializar los atributos, imprimir el valor del lado con un tamaño mayor y  el tipo de triángulo que es (equilátero, isósceles o escaleno).

# %%
class Triangulo:
  def __init__(self, l1, l2, l3):
    self.l1=l1
    self.l2=l2
    self.l3=l3
  def tipo (self):
    if self.l1== self.l2 == self.l3:
      return " EQUILATERO "
    if self.l1 != self.l2 != self.l3:
      return " ESCALENO "
    if self.l1 == self.l2 and self.l3!= self.l1 or self.l1 == self.l3 and self.l2!=self.l1 or self.l3 == self.l2 and self.l1!=self.l3: 
      return " ISOSCELES "
  def ladomayor(self):
    if self.l1>self.l2:
      x=self.l1
    else: x=self.l2
    if x>self.l3:
      return x
    else:
      return self.l3


c1=Triangulo(5, 5, 5) # CASO 1. Triangulo equilatero
print(c1.tipo())
print("El lado mayor mide: ", c1.ladomayor())

c2=Triangulo(3, 4, 5) # Caso 2. Triangulo escaleno
print(c2.tipo())
print("El lado mayor mide: ", c2.ladomayor())

c3=Triangulo(3, 4, 4) # Caso 3. Triangulo isosceles
print(c3.tipo())
print("El lado mayor mide: ", c3.ladomayor())

# %% [markdown]
# ##Ejercicio 4
# Realizar un programa en el cual se declaren dos valores enteros por teclado utilizando el método __init__. Calcular después la suma, resta, multiplicación y división. Utilizar un método para cada una e imprimir los resultados obtenidos. Llamar a la clase Calculadora.

# %%
class Calculadora:
  def __init__(self, a, b):
    self.a=a
    self.b=b
  
  def operación (self):
    suma= self.a + self.b
    resta= self.a - self.b
    multiplicacion= self.a * self.b
    division=self.a / self.b
    print(suma)
    print(resta)
    print(multiplicacion)
    print(division)

c1=Calculadora(3, 4)
print(c1.operación())

# %%
class Calculadora:
	# iniciamos con el método __init__
	def __init__(self):
		self.a=int(input("Ingrese el primer valor: "))
		self.b=int(input("Ingrese el segundo valor: "))
 
 	# función para imprimir
	def imprimir(self):
		print("Los valores son: ", self.a , "y", self.b)  
  
	# función para sumar
	def suma(self):
		suma=self.a+self.b
		print("El resultado de la suma de los valores es: ",suma)
 
	# función para restar
	def resta(self):
		resta=self.a-self.b
		print("El resultado de la resta de los valores es: ",resta)
 
	# función para calcular el producto
	def multiplicacion(self):
		producto=self.a*self.b
		print("El resultado de la multiplicación de los valores es: ",producto)
 
	# función para dividir
	def division(self):
		cociente=self.a/self.b
		print("El resultado de la división de los valores es: ",cociente)
 
#llamadas a la clase y sus funciones
calcular=Calculadora()
calcular.imprimir()
calcular.suma()
calcular.resta()
calcular.multiplicacion()
calcular.division()

# %% [markdown]
# ##Ejercicio 5
# Realizar una clase que administre una agenda. Se debe almacenar para cada contacto el nombre, el teléfono y el email. Además deberá mostrar un menú con las siguientes opciones
#
#
#
# *   Añadir contacto
# *   Lista de contactos
# *   Buscar contacto
# *   Editar contacto
# *   Cerrar agenda

# %%
# Clase

class Agenda:
  #función principal para iniciar clase
  def __init__(self):
    #lista de almacenamiento para contactos
    self.contenido=[]

  #Función que muestra menú, lee y valida la opción ingresada
  def menu(self):
    print(" ")
    print("--- AGENDA 2022 DEVF GEN 16 ---")
    print("**************************************************")
    print("1. AÑADIR CONTACTO")
    print("2. LISTA DE CONTACTOS")
    print("3. BUSCAR CONTACTO")
    print("4. EDITAR CONTACTO")
    print("5. SALIR")
    print("**************************************************")
    print("--- INGRESE EL NUMERO DE LA OPCIÓN QUE DESEE CONSULTAR ---")
    print(" ")

    #Solicitamos la opción al usuario
    opcion=int(input())

    if opcion==1:
      print(" ")
      print("--- AÑADIR CONTACTO --- ")
      self.add()
      self.menu()
    elif opcion==2:
      print(" ")
      print("--- LISTA DE CONACTOS --- ")
      self.vercontactos()
      self.menu()
    elif opcion==3:
      print(" ")
      print("--- BUSCAR CONTACTO --- ")
      self.busqueda()
      self.menu()
    elif opcion==4:
      print(" ")
      print("--- EDITAR CONTACTO --- ")
      self.editar()
      self.menu()
    elif opcion==5:
      print(" ")
      print("--- USTED SALIÓ DE LA AGENDA 2022 DEVF GEN 16 --- ")
      exit()
    elif opcion>5 or opcion<1:
      print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! ")
      print("--- INGRESE UNA OPCIÓN VALIDA ENTRE 1 Y 5 ---")
      print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! ")
      self.menu()

#función de añadir/guardar contacto
  def add(self):
    print(" ")
    nom=input("Ingresar nombre: ")
    tel=int(input("Ingresar telefono: "))
    mail=input("Ingresar e-mail: ")
    self.contenido.append({'nombre':nom,'telefono':tel,'email':mail})

#función para imprimiri lista de contactos
  def vercontactos(self):
    print("")
    a=len(self.contenido)
    if a==0:
      print("AUN NO HAY CONTACTOS GUARDADOS :(")
    else:
      for x in range(a):
        print(self.contenido[x])
        print(" ")

  #función para buscar contacto por nombre
  def busqueda(self):
     print(" ")
     a=len(self.contenido)
     if a==0:
       print("AUN NO HAY CONTACTOS GUARDADOS :(")
     else:
       bus=input("Ingrese el nombre de contacto que desea visualizar: ")
       for x in range(a):
         if bus==self.contenido[x]['nombre']:
           print(self.contenido[x])
           return x
         else:
           if x==a-1 and bus!=self.contenido[x]['nombre']:
             print("EL CONTACTO ", bus, "NO EXISTE :(")

# funcion para editar contacto
  def editar(self):
    #llamamos a la función buscar para imprimir los datos del contacto a editar
    b=self.busqueda()
    print("Seleccione la opción que desee modificar: ")
    print("")
    print("1. Nombre")
    print("2. Teléfono")
    print("3. email")
    #el usuario ingresa la accrion deseada
    c=int(input())
    if c==1:
      nom=input("Ingrese el nuevo nombre: ")
      self.contenido[b]['nombre']=self.nom
    elif c==2:
      telf=input("Ingrese el nuevo teléfono: ")
      self.contenido[b]['telefono']=self.tel
    elif c==3:
      email=input("Ingrese el nuevo email: ")
      self.contactos[b]['email']=self.elaromail
    elif c!=1 and c!=2 and c!=3:
      print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! ")
      print("--- INGRESE UNA OPCIÓN VALIDA ENTRE 1 Y 3 ---")
      print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! ")
	

inicio=Agenda()
inicio.menu()

# %% [markdown]
# ##Ejercicio 6
# En un banco tienen clientes que pueden hacer depósitos y extracciones de dinero. El banco requiere también al final del día calcular la cantidad de dinero que se ha depositado.
#
# Se deberán crear dos clases, la clase cliente y la clase banco. La clase cliente tendrá los atributos nombre y cantidad y los métodos __init__, depositar, extraer, mostrar_total.
#
# La clase banco tendrá como atributos 3 objetos de la clase cliente y los métodos __init__, operar y deposito_total.

# %%
class Banco:
  def __init__(self):
    self.p1=Cliente("Ana")
    self.p2=Cliente("Oscar")
    self.p3=Cliente("Fernanda")
  
  def operar(self):
    self.p1.depositar(678)
    self.p2.depositar(987)
    self.p3.depositar(890)
    self.p1.extraer(321)
    self.p2.extraer(654)
    self.p3.extraer(543)

  def deposito_total(self):
    total=self.p1.depyesx()+self.p2.depyesx()+self.p3.depyesx()
    print("Capital disponible en el banco: ", total)
    print(self.p1.mostrar_total())
    print(self.p2.mostrar_total())
    print(self.p3.mostrar_total())

class Cliente:
  def __init__(self, nombre):
    self.nombre=nombre
    self.cantidad=0

  def depositar(self, cantidad):
    self.cantidad+=cantidad
    #print(self.cantidad)

  def extraer(self, cantidad):
    self.cantidad-=cantidad
    #print(self.cantidad)
  
  def depyesx(self):
    return self.cantidad

  def mostrar_total(self):
    return(self.nombre, " tiene depositada una cantidad de ",self.cantidad)

  
exp=Banco()
exp.operar()
exp.deposito_total()

# %% [markdown]
# ##Ejercicio 7
# Desarrollar un programa que conste de una clase padre Cuenta y dos subclases PlazoFijo y CajaAhorro. Definir los atributos titular y cantidad y un método para imprimir los datos en la clase Cuenta. La clase CajaAhorro tendrá un método para heredar los datos y uno para mostrar la información.
#
# La clase PlazoFijo tendrá dos atributos propios, plazo e interés. Tendrá un método para obtener el importe del interés (cantidad*interés/100) y otro método para mostrar la información, datos del titular plazo, interés y total de interés.
#
# Crear al menos un objeto de cada subclase.

# %%
# creamos la clase Cuenta
class Cuenta:
	# inicializamos los atributos de la clase
	def __init__(self,titular,cantidad):
		self.titular=titular
		self.cantidad=cantidad
 
	# imprimimos los datos
	def imprimir(self):
		print("Titular: ",self.titular)
		print("Cantidad: ", self.cantidad)
 
 
# creamos la clase CajaAhorro
# esta clase hereda atributos de la clase Cuenta
class CajaAhorro(Cuenta):
	# iniciamos los atributos de la clase
	def __init__(self,titular,cantidad):
		super().__init__(titular,cantidad)
 
	# imprimimos los datos de la cuenta
	def imprimir(self):
		print("Cuenta de caja de ahorros")
		super().imprimir()
 
 
# creamos la clase PlazoFijo
# esta clase también hereda atributos de la clase Cuenta
class PlazoFijo(Cuenta):
	# inicializamos los atributos de la clase
	def __init__(self,titular,cantidad,plazo,interes):
		super().__init__(titular,cantidad)
		self.plazo=plazo
		self.interes=interes
 
 
	# calculamos la ganancia
	def ganancia(self):
		ganancia=self.cantidad*self.interes/100
		print("El importe de interés es: ",ganancia)
 
 
	# imprimimos los resultados
	def imprimir(self):
		print("Cuenta a plazo fijo")
		super().imprimir()
		print("Plazo disponible en días: ",self.plazo)
		print("Interés: ",self.interes)
		self.ganancia()
 
 
# bloque principal
caja1=CajaAhorro("Manuel",5000)
caja1.imprimir()
 
plazo1=PlazoFijo("Isabel",8000,365,1.2)
plazo1.imprimir()

# %% [markdown]
# opciones de solución a prblemas propuestos en:
# https://byte-mind.net/curso-python-poo/
